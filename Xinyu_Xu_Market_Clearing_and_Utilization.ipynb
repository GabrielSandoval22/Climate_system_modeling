# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajjme/Climate_system_modeling/blob/main/Xinyu_Xu_Market_Clearing_and_Utilization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# ==============================
# 1.1.1 Initial Generation - Requires IEA historical data
# ==============================
#initial_generation = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#    "new": 0}

# ==============================
# 1.1.2.1 Compute Avg Embodied Fixed Cost
# ==============================
# Embodied fixed cost
#embodied_fixed_cost_existing = {
#   "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#    "new": None}

# Electricity supply capacity
#elec_energy_supply_capacity = {
#    "thermal": None,
#    "renewable": None,
#   "nuclear": None,
#   "new": None}

# Adjusted capital cost
#adjusted_capital_cost = {
#    "thermal": None,
#    "renewable": None,
#   "nuclear": None,
#    "new": None
#}

# Compute average embodied fixed cost
#avg_embodied_fixed_cost = {
#    key: max(0, embodied_fixed_cost_existing[key] / max(1, elec_energy_supply_capacity[key]))
#    for key in initial_generation
#}

# ==============================
# 1.1.2.2 Compute Variable Cost of Electricity Supply
# ==============================
# Base variable cost
#variable_cost_without_adjustments = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#    "new": None
#}

# Net unit taxes adjustments
#net_unit_taxes = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#    "new": None
#}

# Minimum unit cost constraint
#min_unit_cost = None

# Compute final variable cost
#variable_cost_supply = {
#    key: max(min_unit_cost, variable_cost_without_adjustments[key] + net_unit_taxes[key])
#    for key in initial_generation
#}

# ==============================
# 1.1.2 Compute Reference Busbar Electricity Price
# ==============================
# Compute total cost
#total_cost = sum(
#    initial_generation[key] * (avg_embodied_fixed_cost[key] + variable_cost_supply[key])
#    for key in initial_generation
#)
# Compute total electricity generation
#total_generation = sum(initial_generation.values())

# Compute reference busbar electricity price
#reference_busbar_price = total_cost / max(1, total_generation)  # Avoid division by zero

# ==============================
# 1.2 Compute Change in Electricity Price
# ==============================
# Target electricity price
#saturation_market_price = None
#target_elec_price = None

# Compute indicated electricity price
#indicated_elec_price = min(saturation_market_price, target_elec_price)

# Price adjustment time
#price_adjustment_time = None

# Compute change in electricity price
#change_in_elec_price = (indicated_elec_price - reference_busbar_price) / price_adjustment_time


# Compute Busbar Electricity Price

#busbar_electricity_price = reference_busbar_price + change_in_elec_price


# Output results

#print(f"Reference Busbar Electricity Price: {reference_busbar_price}")
#print(f"Indicated Electricity Price: {indicated_elec_price}")
#print(f"Change in Electricity Price: {change_in_elec_price}")
#print(f"Busbar Electricity Price: {busbar_electricity_price}")

# %%
import numpy as np

# ==============================
# 1.2 Reference price of fuels (Initial fuel price) - Values need to be filled manually
# ==============================
#ref_price_of_fuels = {
# "thermal":  2.4
#  "renewable": 11
#  "nuclear":  4.1
#}

# ==============================
# 1.1.3 Price adjustment time
# ==============================
# price_adjustment_time= 0.5

# ==============================
# 1.1.1.1 Saturation market price of fuels
# ==============================
#saturation_multiplier = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#}

#saturation_market_price_of_fuels = {
#    key: ref_price_of_fuels[key] * saturation_multiplier[key]
#    for key in ref_price_of_fuels
#}

# ==============================
# 1.1.1.2 Target price of fuels
# ==============================
#effect_of_demand_supply_balance = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#}

#effect_of_fuel_cost_on_indicated_price = {
#    "thermal": None,
#    "renewable": None,
#    "nuclear": None,
#}

#target_price_of_fuels = {
#   key: None  # Placeholder, will be calculated using market price dynamically
#   for key in ref_price_of_fuels
#}

# ==============================
# 1.1.1 Indicated price of fuels
# ==============================
#indicated_price_of_fuels = {
# key: min(saturation_market_price_of_fuels[key], target_price_of_fuels[key])
# for key in ref_price_of_fuels
#}

# ==============================
# 1.1 Change in fuel price
# ==============================
#change_in_fuel_price = {
#    key: (indicated_price_of_fuels[key] - None) / price_adjustment_time  # Market price placeholder
#    for key in ref_price_of_fuels
#}

# ==============================
# 1.1.2 Market price of fuels
# ==============================
#market_price_of_fuels = {
#    key: ref_price_of_fuels[key] + change_in_fuel_price[key]
#    for key in ref_price_of_fuels
#}

# ==============================
# Output results (placeholders until values are filled)
# ==============================
#for fuel, price in market_price_of_fuels.items():
#   print(f"Market price of {fuel}: {price}")

# %%
Busbar electricity price
 =
INTEG(
Change in elec price
,
Reference busbar elec price
 )

Reference busbar elec price = 24.4

Change in elec price
 =
(
Indicated elec price - find equation
 −
Busbar electricity price - connects to above
 ) /
Price adjustment time = 0.5

Indicated elec price
 =
MIN(
Saturation market price of electricity = 97.8 #param Enroads
,
Target elec price # has whole equation will research later
 )
Target elec price
 =
Busbar electricity price
 *
Effect of elec demand supply balance on price
 *
Effect of elec cost on indicated price

Effect of elec demand supply balance on price
 =
Electricity demand supply balance
 ^
Sensitivity of price to demand supply balance

Sensitivity of price to demand supply balance = 1

#we are using the ratio of suppy and demand to predict price


Electricity demand supply balance
 =
ZIDZ(
Total electric energy demand
,
Total electricity production (this includes CCS From Gabes Module)  (this will be the base give us a template value for now)
 )

Total electric energy demand
 =
SUM(
Electric energy demand[EndUseSector]
 ) Our connection To Andrew's Module!!!! #andrew will provide something like this Electric energy demand = {"Residential and Commercial": 80, "Industrial": 60, "Transport": 30}

                # Electric energy demand[EndUseSector]
                # =
                # End use electric demand capacity[EndUseSector]
                # *
                # Elec demand capital utilization
                # +
                # Added energy requirements[Carrier, EndUseSector]

# %%
Effect of elec cost on indicated price
 =
1 +
Sensitivity of price to cost
 * (
Weighted avg cost of electricity
 /
Busbar electricity price
 − 1 )

 Sensitivity of price to cost
 =
0.2

Weighted avg cost of electricity
 =
SUM(
Electricity production[Elec Paths] #from Andrew Module by Elec path
 *
Unit cost of elec supply[Elec Paths]
 ) /
Total electricity production


Unit cost of elec supply[All elec but new]
 =
Avg embodied fixed cost of elec capacity[Elec Paths]
 +
Variable cost of elec supply[Elec Paths]
 +
Net capital cost for elec CCS by fuel weighted by existing share[Elec Paths]
 +
Net variable cost for elec CCS per GJ weighted by existing share[Elec Paths]
Unit cost of elec supply[new]
 =
IF THEN ELSE( Time <=
Breakthrough success year for elec[new]
, :NA:,
Avg embodied fixed cost of elec capacity[new]
 +
Variable cost of elec supply[new]
 )

# %%
#this code will turn the inputed energy suppy values into cost based on fixed cost and variable cost

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
REFERENCE_BUSBAR_ELEC_PRICE = 24.4  # Reference busbar electricity price
PRICE_ADJUSTMENT_TIME = 0.5  # Price adjustment time
SATURATION_MARKET_PRICE = 97.8  # Saturation market price of electricity

# Assume the Target electric price for demonstration purposes (you can replace it with a dynamic formula)
def target_electric_price(time):
    # For simplicity, let's assume a linear increase in the target electric price
    return 30 + 0.2 * time  # Replace with your actual target price equation

# Function to calculate the indicated electric price
def indicated_electric_price(time):
    target_price = target_electric_price(time)
    return min(SATURATION_MARKET_PRICE, target_price)

# Function to calculate the change in electric price
def change_in_electric_price(busbar_price, time):
    indicated_price = indicated_electric_price(time)
    return (indicated_price - busbar_price) / PRICE_ADJUSTMENT_TIME

# Function to integrate the change in electric price over time to update busbar electricity price
def update_busbar_price(time_steps):
    busbar_price = REFERENCE_BUSBAR_ELEC_PRICE
    busbar_prices = [busbar_price]

    for i, t in enumerate(time_steps[1:], start=1):  # Using enumerate to get index
        change = change_in_electric_price(busbar_price, t)
        # Update busbar price based on the change (we assume a simple Euler method for integration)
        delta_t = t - time_steps[i-1]
        busbar_price += change * delta_t
        busbar_prices.append(busbar_price)

    return np.array(busbar_prices)

# Time steps for simulation (e.g., from 0 to 50 in steps of 0.1)
time_steps = np.arange(0, 50, 0.1)

# Calculate busbar prices over time
busbar_prices = update_busbar_price(time_steps)

# Plot the results
plt.plot(time_steps, busbar_prices, label='Busbar Electricity Price')
plt.xlabel('Time')
plt.ylabel('Busbar Price (in $)')
plt.title('Busbar Electricity Price Over Time')
plt.legend()
plt.grid(True)
plt.show()
